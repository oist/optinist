# %% [markdown]
# `conda env create -n lccd_env -f optinist/conda/lccd_env.yaml`

# %%
# !pip install pynwb

# %%
import os
import sys
sys.path.append(os.path.abspath('..'))

# %%
from studio.wrappers.lccd import lccd_detection
from studio.dataclass import ImageData

# %%
sample_data = ImageData(["../sample_data/mouse2p_2_donotouse.tiff"])

# %%
lccd_detection_params = {
    'blob_detector': {
      'filtersize1': 100,
      'filtersize2': 4,
      'sigma': 1.25,
      'fsize': 30,
      'min_area': 20,
      'max_area': 50,
      'sparse': False
    },
    'roi_integration': {
      'overlap_threshold': 0.4,
      'min_area': 20,
      'max_area': 100,
      'sparse': False
    },
    'lccd': {
      'frame_divider': 100
    },
    'dff': {
      'f0_frames': 100,
      'f0_percentile': 8
    }
}

# %%
ret = lccd_detection.lccd_detect(sample_data, lccd_detection_params)

# %%
ret
